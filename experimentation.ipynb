# %% [markdown]
# # Experimentation
#
# ## Data Ingestion

# %%
import os
import pandas as pd

# %%
pwd
# Out:
# '/Users/macbook/Documents/workspace_datahackerman/tesco_customer_churn'

# %%
FILE_NAME = "CustomerChurn.csv"
DATA_FOLDER = "data"

# %%
main_path = os.getcwd()
main_path
# Out:
# '/Users/macbook/Documents/workspace_datahackerman/tesco_customer_churn'

# %%
file_path = os.path.join(os.path.join(main_path, DATA_FOLDER), FILE_NAME)
file_path
# Out:
# '/Users/macbook/Documents/workspace_datahackerman/tesco_customer_churn/data/CustomerChurn.csv'

# %%
# %%time

churn_data = pd.read_csv(file_path)
# Out:
# CPU times: user 43 ms, sys: 11.8 ms, total: 54.8 ms
# Wall time: 66.9 ms

# %%
churn_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# Adjust column headers to lowercase

# %%
churn_data.columns = map(str.lower, churn_data.columns)

# %%
churn_data.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity  ... deviceprotection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
churn_data.shape
# Out:
# (7043, 21)

# %% [markdown]
# ## Data Inspection

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   seniorcitizen     7043 non-null   int64
#  3   partner           7043 non-null   object
#  4   dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   object
#  7   multiplelines     7043 non-null   object
#  8   internetservice   7043 non-null   object
#  9   onlinesecurity    7043 non-null   object
#  10  onlinebackup      7043 non-null   object
#  11  deviceprotection  7043 non-null   object
#  12  techsupport       7043 non-null   object
#  13  streamingtv       7043 non-null   object
#  14  streamingmovies   7043 non-null   object
#  15  contract          7043 non-null   object
# ...

# %% [markdown]
# Only tenure , monthlycharges and totalcharges are Numerical Variables.

# %% [markdown]
# churndata.totalcharges data type needs modification

# %% [markdown]
# to unify decimal places with Monthly and modify to float data type

# %%
churn_data["totalcharges"] = churn_data["totalcharges"].astype(float)

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   seniorcitizen     7043 non-null   int64
#  3   partner           7043 non-null   object
#  4   dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   object
#  7   multiplelines     7043 non-null   object
#  8   internetservice   7043 non-null   object
#  9   onlinesecurity    7043 non-null   object
#  10  onlinebackup      7043 non-null   object
#  11  deviceprotection  7043 non-null   object
#  12  techsupport       7043 non-null   object
#  13  streamingtv       7043 non-null   object
#  14  streamingmovies   7043 non-null   object
#  15  contract          7043 non-null   object
# ...

# %%
churn_data.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity  ... deviceprotection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
churn_data.tail()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      phoneservice     multiplelines internetservice onlinesecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      deviceprotection techsupport streamingtv streamingmovies        contract  \
# ...

# %% [markdown]
# to check for missing values

# %%
churn_data.isna().sum()
# Out:
# customerid          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %% [markdown]
# to check for duplicates

# %%
churn_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# . Statistical Analysis
# . Plots
# . Correlation

# %% [markdown]
# To compute basic descriptive statistics

# %% [markdown]
# Calculate average tenure

# %%
churn_data["tenure"].mean()
# Out:
# 32.37114865824223

# %% [markdown]
# Calculate average monthly charge

# %%
churn_data["monthlycharges"].mean()
# Out:
# 64.76169246059918

# %% [markdown]
# Calculate average total charge

# %%
churn_data["totalcharges"].mean()
# Out:
# 2279.7343035638223

# %% [markdown]
# Aggregate tenure, Monthly Charges and Total Charges by gender

# %%
churn_data[["gender", "tenure"]].groupby("gender").mean()
# Out:
#            tenure
# gender
# Female  32.244553
# Male    32.495359

# %%
churn_data[["gender", "monthlycharges"]].groupby("gender").mean()
# Out:
#         monthlycharges
# gender
# Female       65.204243
# Male         64.327482

# %%
churn_data[["gender", "totalcharges"]].groupby("gender").mean()
# Out:
#         totalcharges
# gender
# Female   2279.918062
# Male     2279.554008

# %% [markdown]
# Create additional columns

# %%
churn_data.tenure.min(),churn_data.tenure.max()
# Out:
# (0, 72)

# %%
churn_data.monthlycharges.min(),churn_data.monthlycharges.max()
# Out:
# (18.25, 118.75)

# %%
churn_data.totalcharges.min(),churn_data.totalcharges.max()
# Out:
# (0.0, 8684.8)

# %% [markdown]
# Group customers based on tenure

# %%
# churn_data["tenure_group"]=pd.cut(churn_data["tenure"],
#      bins=[-1,25,48,73],labels=['Low','Medium','High'])

# %%
# churn_data["MonthlyCharges_group"]=pd.cut(churn_data["tenure"],
#                                  bins=[18,52,85,119],labels=['Low','Medium','High'])

# %%
#churn_data["TotalCharges_group"]=pd.cut(churn_data["TotalCharges"],
 #                                 bins=[0,2895,5790,8685],labels=['Low','Medium','High'])

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   seniorcitizen     7043 non-null   int64
#  3   partner           7043 non-null   object
#  4   dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   object
#  7   multiplelines     7043 non-null   object
#  8   internetservice   7043 non-null   object
#  9   onlinesecurity    7043 non-null   object
#  10  onlinebackup      7043 non-null   object
#  11  deviceprotection  7043 non-null   object
#  12  techsupport       7043 non-null   object
#  13  streamingtv       7043 non-null   object
#  14  streamingmovies   7043 non-null   object
#  15  contract          7043 non-null   object
# ...

# %%
churn_data.sample(5)
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 6805  4323-OHFOW  Female              1     Yes         No      70
# 6852  2408-PSJVE    Male              0     Yes        Yes      44
# 5177  3672-YITQD    Male              1     Yes         No      36
# 4428  5449-FIBXJ    Male              0     Yes        Yes      19
# 642   0970-ETWGE    Male              0      No         No       1
#
#      phoneservice multiplelines internetservice onlinesecurity  ...  \
# 6805          Yes           Yes     Fiber optic             No  ...
# 6852          Yes            No             DSL             No  ...
# 5177          Yes           Yes     Fiber optic             No  ...
# 4428          Yes           Yes     Fiber optic             No  ...
# 642           Yes            No     Fiber optic             No  ...
#
#      deviceprotection techsupport streamingtv streamingmovies        contract  \
# ...

# %%
# Compute average tenure charge per customer

# %%
# def calculate_average_tenure_charge(TotalCharges,tenure):
   # """This function calculates average tenure charge per customer"""

   # result = churn_data["TotalCharges"] /churn_data["tenure"]

 #   return result

# %%
# churn_data["AverageTenureCharge"] = calculate_average_tenure_charge

# %%
# churn_data.head()

# %%
# churn_data.AverageTenureCharge = churn_data.AverageTenureCharge.str.replace(' ','0')

# %%
# churn_data["AverageTenureCharge"] = churn_data["AverageTenureCharge"].astype(float)

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   seniorcitizen     7043 non-null   int64
#  3   partner           7043 non-null   object
#  4   dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   object
#  7   multiplelines     7043 non-null   object
#  8   internetservice   7043 non-null   object
#  9   onlinesecurity    7043 non-null   object
#  10  onlinebackup      7043 non-null   object
#  11  deviceprotection  7043 non-null   object
#  12  techsupport       7043 non-null   object
#  13  streamingtv       7043 non-null   object
#  14  streamingmovies   7043 non-null   object
#  15  contract          7043 non-null   object
# ...

# %%
churn_data.sample(5)
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 2874  8347-GDTMP  Female              0     Yes         No      64
# 2643  3550-SAHFP  Female              0      No         No      33
# 5079  2507-QZPQS    Male              0      No         No      15
# 3794  4280-DLSHD    Male              0     Yes         No       8
# 6708  2272-QAGFO  Female              1      No         No      14
#
#      phoneservice multiplelines internetservice       onlinesecurity  ...  \
# 2874          Yes            No              No  No internet service  ...
# 2643          Yes           Yes     Fiber optic                   No  ...
# 5079          Yes           Yes     Fiber optic                   No  ...
# 3794          Yes            No             DSL                   No  ...
# 6708          Yes           Yes     Fiber optic                   No  ...
#
#          deviceprotection          techsupport          streamingtv  \
# ...

# %% [markdown]
# ## Model Building

# %%
#churn_data.sample()

# %% [markdown]
# ## Prepare Dataset for Modelling

# %%
churn_data.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity  ... deviceprotection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Train_Test_Split

# %%
# 0.3, 0.7

# %%
from sklearn.model_selection import train_test_split

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
# y = mX + c

# %%
X = churn_data[["customerid","gender","seniorcitizen",
                "partner","dependents","tenure",
                "phoneservice","multiplelines","internetservice",
                "onlinesecurity","deviceprotection","techsupport",
                "streamingtv","streamingmovies","contract",
                "paperlessbilling","paymentmethod",
                "monthlycharges","totalcharges"]]

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity deviceprotection  \
# 0  No phone service             DSL             No               No
# 1                No             DSL            Yes              Yes
# 2                No             DSL            Yes               No
# 3  No phone service             DSL            Yes              Yes
# 4                No     Fiber optic             No               No
#
#   techsupport streamingtv streamingmovies        contract paperlessbilling  \
# ...

# %%
y = churn_data["churn"]

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: churn, dtype: object

# %%
y[0:5]
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: churn, dtype: object

# %%
train_data, test_data = train_test_split(churn_data,test_size = 0.30, random_state =42)

# %%
train_data.shape, test_data.shape
# Out:
# ((4930, 21), (2113, 21))

# %%
train_data.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 1695  4906-ZHGPK    Male              0     Yes        Yes      54
# 1095  7439-DKZTW    Male              0      No         No       1
# 3889  2592-HODOV    Male              0      No         No      13
# 3667  7826-VVKWT  Female              1     Yes        Yes      24
# 2902  1658-TJVOA  Female              1      No         No       6
#
#      phoneservice multiplelines internetservice       onlinesecurity  ...  \
# 1695          Yes           Yes             DSL                   No  ...
# 1095          Yes            No     Fiber optic                   No  ...
# 3889          Yes            No              No  No internet service  ...
# 3667          Yes            No     Fiber optic                   No  ...
# 2902          Yes            No     Fiber optic                  Yes  ...
#
#          deviceprotection          techsupport          streamingtv  \
# ...

# %%
test_data.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# 2715          Yes               Yes              No  No internet service  ...
# 3825          Yes                No              No  No internet service  ...
# 1807          Yes                No     Fiber optic                   No  ...
# 132           Yes                No             DSL                   No  ...
#
#          deviceprotection          techsupport          streamingtv  \
# ...

# %%
label = 'churn'

# %%
print("Summary of churn variable:\n", train_data[label].describe())
# Out:
# Summary of churn variable:
#  count     4930
# unique       2
# top         No
# freq      3635
# Name: churn, dtype: object

# %% [markdown]
# ## basic model build

# %%
# %%time

save_path = 'agModels-predictchurn'
predictor = TabularPredictor(label=label, path=save_path).fit(train_data)
# Out:
# ...
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictchurn/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.16
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 20.6.0: Fri Dec 16 00:35:00 PST 2022; root:xnu-7195.141.49~1/RELEASE_X86_64
# Train Data Rows:    4930
# Train Data Columns: 20
# Label Column: churn
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['No', 'Yes']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = Yes, class 0 = No
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Yes) vs negative (No) class.
# ...

# %%
predictor.leaderboard(silent=True)
# Out:
#                   model  score_val  pred_time_val  fit_time  \
# 0              CatBoost      0.814       0.008851  5.517798
# 1   WeightedEnsemble_L2      0.814       0.011298  6.451184
# 2        NeuralNetTorch      0.802       0.023423  6.683447
# 3       NeuralNetFastAI      0.792       0.021748  8.822634
# 4      RandomForestEntr      0.784       0.148517  1.298468
# 5               XGBoost      0.782       0.012325  0.691018
# 6      RandomForestGini      0.774       0.076403  2.297627
# 7        ExtraTreesGini      0.774       0.131301  1.530490
# 8        ExtraTreesEntr      0.768       0.079651  1.439148
# 9        KNeighborsUnif      0.758       0.024328  0.015150
# 10       KNeighborsDist      0.732       0.023120  0.017284
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.008851           5.517798            1       True
# 1                 0.002447           0.933386            2       True
# ...

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# load test data to make predictions

# %%
y_test = test_data[label]

# %%
y_test.head()
# Out:
# 185     Yes
# 2715     No
# 3825     No
# 1807    Yes
# 132      No
# Name: churn, dtype: object

# %%
y_test = test_data[label]  # values to predict

# %%
y_test [0:5]
# Out:
# 185     Yes
# 2715     No
# 3825     No
# 1807    Yes
# 132      No
# Name: churn, dtype: object

# %%
test_data_nolab = test_data.drop(columns=[label])  # delete label column to avoid cheating

# %%
test_data_nolab.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      phoneservice     multiplelines internetservice       onlinesecurity  \
# 185            No  No phone service             DSL                   No
# 2715          Yes               Yes              No  No internet service
# 3825          Yes                No              No  No internet service
# 1807          Yes                No     Fiber optic                   No
# 132           Yes                No             DSL                   No
#
#              onlinebackup     deviceprotection          techsupport  \
# ...

# %%
save_path
# Out:
# 'agModels-predictchurn'

# %%
predictor

# %%
save_model_predictor = TabularPredictor.load(save_path)

# %%
save_model_predictor

# %%
y_pred = save_model_predictor.predict(test_data_nolab)

# %%
y_pred[0:5]
# Out:
# 185     Yes
# 2715     No
# 3825     No
# 1807    Yes
# 132      No
# Name: churn, dtype: object

# %%
print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: accuracy on test data: 0.8031235210601041
# Evaluations on test data:
# {
#     "accuracy": 0.8031235210601041,
#     "balanced_accuracy": 0.7124592194125784,
#     "mcc": 0.4686569946165508,
#     "f1": 0.5864811133200795,
#     "precision": 0.6828703703703703,
#     "recall": 0.5139372822299652
# }
# Predictions:
#  185     Yes
# 2715     No
# 3825     No
# 1807    Yes
# 132      No
#        ...
# 5522    Yes
# 6377     No
# 5500     No
# 2392     No
# 6705     No
# Name: churn, Length: 2113, dtype: object

# %%
save_model_predictor.leaderboard(test_data, silent=True)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0              CatBoost    0.803124      0.814        0.025866       0.008851
# 1   WeightedEnsemble_L2    0.803124      0.814        0.030563       0.011298
# 2               XGBoost    0.803124      0.782        0.090804       0.012325
# 3        NeuralNetTorch    0.801704      0.802        0.082186       0.023423
# 4       NeuralNetFastAI    0.798864      0.792        0.303365       0.021748
# 5      RandomForestGini    0.798391      0.774        0.264374       0.076403
# 6      RandomForestEntr    0.793658      0.784        0.248574       0.148517
# 7        ExtraTreesGini    0.781827      0.774        0.306667       0.131301
# 8        ExtraTreesEntr    0.781354      0.768        0.596075       0.079651
# 9        KNeighborsUnif    0.773308      0.758        0.031147       0.024328
# 10       KNeighborsDist    0.766209      0.732        0.011551       0.023120
#
# ...

# %%
test_data.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# 2715          Yes               Yes              No  No internet service  ...
# 3825          Yes                No              No  No internet service  ...
# 1807          Yes                No     Fiber optic                   No  ...
# 132           Yes                No             DSL                   No  ...
#
#          deviceprotection          techsupport          streamingtv  \
# ...

# %% [markdown]
# ## Improving Predictive Performance

# %% [markdown]
# Our basic model build took 31.9 seconds, we can improve our model by setting a shorter time limit of 25 seconds

# %%
#time_limit = 25

# %% [markdown]
# We can also set an evaluation metric

# %%
#metric = 'roc_auc'

# %%
#save_path = 'agModels-predictchurnimproved'

# %% [markdown]
# .. and also preset our models for best quality fit

# %%
# %%time

time_limit = 20
save_path = 'AutogluonModels'
metric = 'roc_auc'
predictor = TabularPredictor(label, eval_metric=metric).fit(train_data, time_limit=time_limit, presets='best_quality')
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230219_203642/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 20s
# AutoGluon will save models to "AutogluonModels/ag-20230219_203642/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.16
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 20.6.0: Fri Dec 16 00:35:00 PST 2022; root:xnu-7195.141.49~1/RELEASE_X86_64
# Train Data Rows:    4930
# Train Data Columns: 20
# Label Column: churn
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['No', 'Yes']
# ...

# %%
predictor.leaderboard(test_data, silent=True)
# Out:
#                      model  score_test  score_val  pred_time_test  \
# 0      WeightedEnsemble_L2    0.860705   0.842965        1.153371
# 1          CatBoost_BAG_L1    0.860653   0.842803        0.062715
# 2  RandomForestGini_BAG_L1    0.837488   0.820652        0.548476
# 3  RandomForestEntr_BAG_L1    0.837081   0.820211        0.522152
# 4    ExtraTreesGini_BAG_L1    0.831588   0.808307        0.961456
# 5    KNeighborsUnif_BAG_L1    0.751180   0.730969        0.008581
# 6    KNeighborsDist_BAG_L1    0.742869   0.720020        0.008434
#
#    pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       1.004899  18.090163                 0.011594                0.001209
# 1       0.119853  13.890118                 0.062715                0.119853
# 2       0.400431   1.309332                 0.548476                0.400431
# 3       0.462974   1.607918                 0.522152                0.462974
# ...

# %% [markdown]
# Model building results show only 7 models can complete iteration within time limit set

# %%
#Bringing it all together

# %%
test_data["predicted_churn"] = y_pred

# %%
test_data.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# 2715          Yes               Yes              No  No internet service  ...
# 3825          Yes                No              No  No internet service  ...
# 1807          Yes                No     Fiber optic                   No  ...
# 132           Yes                No             DSL                   No  ...
#
#               techsupport          streamingtv      streamingmovies  \
# ...

# %%
test_data.sample(10)
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 5936  9418-RUKPH  Female              0     Yes        Yes      38
# 6422  8668-KNZTI    Male              0      No         No      52
# 6049  7634-HLQJR  Female              0     Yes        Yes      47
# 2623  3130-ICDUP  Female              0      No        Yes       2
# 5589  7253-UVNDW  Female              0      No         No      46
# 6388  1963-VAUKV  Female              0      No         No       1
# 93    6067-NGCEU  Female              0      No         No      65
# 3973  3441-CGZJH  Female              0     Yes        Yes      43
# 5391  8124-NZVGJ  Female              0      No         No       6
# 5720  2325-WINES  Female              0      No         No      32
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 5936          Yes                No              No  No internet service  ...
# ...
