# %% [markdown]
# # Experimentation
#
# ## Data Ingestion

# %%
import os
import pandas as pd

# %%
pwd
# Out:
# '/Users/macbook/Documents/workspace_datahackerman/tesco_customer_churn'

# %%
FILE_NAME = "CustomerChurn.csv"
DATA_FOLDER = "data"

# %%
main_path = os.getcwd()
main_path
# Out:
# '/Users/macbook/Documents/workspace_datahackerman/tesco_customer_churn'

# %%
file_path = os.path.join(os.path.join(main_path, DATA_FOLDER), FILE_NAME)
file_path
# Out:
# '/Users/macbook/Documents/workspace_datahackerman/tesco_customer_churn/data/CustomerChurn.csv'

# %%
# %%time

churn_data = pd.read_csv(file_path)
# Out:
# CPU times: user 30.7 ms, sys: 7.05 ms, total: 37.7 ms
# Wall time: 53.2 ms

# %%
churn_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# Adjust column headers to lowercase

# %%
churn_data.columns = map(str.lower, churn_data.columns)

# %%
churn_data.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity  ... deviceprotection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   techsupport streamingtv streamingmovies        contract paperlessbilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                paymentmethod monthlycharges  totalcharges churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
churn_data.shape
# Out:
# (7043, 21)

# %% [markdown]
# ## Data Inspection

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   seniorcitizen     7043 non-null   int64
#  3   partner           7043 non-null   object
#  4   dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   object
#  7   multiplelines     7043 non-null   object
#  8   internetservice   7043 non-null   object
#  9   onlinesecurity    7043 non-null   object
#  10  onlinebackup      7043 non-null   object
#  11  deviceprotection  7043 non-null   object
#  12  techsupport       7043 non-null   object
#  13  streamingtv       7043 non-null   object
#  14  streamingmovies   7043 non-null   object
#  15  contract          7043 non-null   object
#  16  paperlessbilling  7043 non-null   object
#  17  paymentmethod     7043 non-null   object
#  18  monthlycharges    7043 non-null   float64
#  19  totalcharges      7043 non-null   object
#  20  churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# Only tenure , monthlycharges and totalcharges are Numerical Variables.

# %% [markdown]
# churndata.totalcharges data type needs modification

# %%
churn_data['totalcharges'] = pd.to_numeric(churn_data['totalcharges'],errors='coerce')

# %%
churn_data.totalcharges
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: totalcharges, Length: 7043, dtype: float64

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   seniorcitizen     7043 non-null   int64
#  3   partner           7043 non-null   object
#  4   dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   object
#  7   multiplelines     7043 non-null   object
#  8   internetservice   7043 non-null   object
#  9   onlinesecurity    7043 non-null   object
#  10  onlinebackup      7043 non-null   object
#  11  deviceprotection  7043 non-null   object
#  12  techsupport       7043 non-null   object
#  13  streamingtv       7043 non-null   object
#  14  streamingmovies   7043 non-null   object
#  15  contract          7043 non-null   object
#  16  paperlessbilling  7043 non-null   object
#  17  paymentmethod     7043 non-null   object
#  18  monthlycharges    7043 non-null   float64
#  19  totalcharges      7032 non-null   float64
#  20  churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
churn_data.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity  ... deviceprotection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   techsupport streamingtv streamingmovies        contract paperlessbilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                paymentmethod monthlycharges  totalcharges  churn
# 0           Electronic check          29.85         29.85     No
# 1               Mailed check          56.95       1889.50     No
# 2               Mailed check          53.85        108.15    Yes
# 3  Bank transfer (automatic)          42.30       1840.75     No
# 4           Electronic check          70.70        151.65    Yes
#
# [5 rows x 21 columns]

# %%
churn_data.tail()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      phoneservice     multiplelines internetservice onlinesecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      deviceprotection techsupport streamingtv streamingmovies        contract  \
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      paperlessbilling              paymentmethod monthlycharges  totalcharges  \
# 7038              Yes               Mailed check          84.80       1990.50
# 7039              Yes    Credit card (automatic)         103.20       7362.90
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40        306.60
# 7042              Yes  Bank transfer (automatic)         105.65       6844.50
#
#       churn
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
#
# [5 rows x 21 columns]

# %% [markdown]
# to check for missing values

# %%
churn_data.isna().sum()
# Out:
# customerid           0
# gender               0
# seniorcitizen        0
# partner              0
# dependents           0
# tenure               0
# phoneservice         0
# multiplelines        0
# internetservice      0
# onlinesecurity       0
# onlinebackup         0
# deviceprotection     0
# techsupport          0
# streamingtv          0
# streamingmovies      0
# contract             0
# paperlessbilling     0
# paymentmethod        0
# monthlycharges       0
# totalcharges        11
# churn                0
# dtype: int64

# %% [markdown]
# to check for duplicates

# %%
churn_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# . Statistical Analysis
# . Plots
# . Correlation

# %% [markdown]
# To compute basic descriptive statistics

# %% [markdown]
# Calculate average tenure

# %%
churn_data["tenure"].mean()
# Out:
# 32.37114865824223

# %% [markdown]
# Calculate average monthly charge

# %%
churn_data["monthlycharges"].mean()
# Out:
# 64.76169246059918

# %% [markdown]
# Calculate average total charge

# %%
churn_data["totalcharges"].mean()
# Out:
# 2283.3004408418656

# %% [markdown]
# Aggregate tenure, Monthly Charges and Total Charges by gender

# %%
churn_data[["gender", "tenure"]].groupby("gender").mean()
# Out:
#            tenure
# gender
# Female  32.244553
# Male    32.495359

# %%
churn_data[["gender", "monthlycharges"]].groupby("gender").mean()
# Out:
#         monthlycharges
# gender
# Female       65.204243
# Male         64.327482

# %%
churn_data[["gender", "totalcharges"]].groupby("gender").mean()
# Out:
#         totalcharges
# gender
# Female   2283.190985
# Male     2283.407861

# %% [markdown]
# Determine mininum and maximum values

# %%
churn_data.tenure.min(),churn_data.tenure.max()
# Out:
# (0, 72)

# %%
churn_data.monthlycharges.min(),churn_data.monthlycharges.max()
# Out:
# (18.25, 118.75)

# %%
churn_data.totalcharges.min(),churn_data.totalcharges.max()
# Out:
# (18.8, 8684.8)

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   seniorcitizen     7043 non-null   int64
#  3   partner           7043 non-null   object
#  4   dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   object
#  7   multiplelines     7043 non-null   object
#  8   internetservice   7043 non-null   object
#  9   onlinesecurity    7043 non-null   object
#  10  onlinebackup      7043 non-null   object
#  11  deviceprotection  7043 non-null   object
#  12  techsupport       7043 non-null   object
#  13  streamingtv       7043 non-null   object
#  14  streamingmovies   7043 non-null   object
#  15  contract          7043 non-null   object
#  16  paperlessbilling  7043 non-null   object
#  17  paymentmethod     7043 non-null   object
#  18  monthlycharges    7043 non-null   float64
#  19  totalcharges      7032 non-null   float64
#  20  churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %% [markdown]
# #Univariate analysis

# %% [markdown]
# ## Plots

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: pandas>=0.25 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.14.0)
# Requirement already satisfied: six>=1.5 in /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import plotly.express as px

# %%
import numpy as np

# %%
sns.countplot(x='churn',data=churn_data)
plt.show()
plt.savefig('images/churnplot')

# %%
sns.countplot(x='churn',hue='gender',data=churn_data)
plt.show()
plt.savefig('images/churnbygender')

# %%
sns.countplot(x='churn',hue='seniorcitizen',data=churn_data)
plt.show()
plt.savefig('images/seniorcitizen')

# %%
sns.countplot(x='churn',hue='contract',data=churn_data)
plt.show()
plt.savefig('images/contract')

# %% [markdown]
# ## Correlation

# %%
plt.figure(figsize=(20, 12))
corr = churn_data.apply(lambda x: pd.factorize(x)[0]).corr()
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, linewidths=.2, annot = True)
plt.savefig('images/correlation')

# %% [markdown]
# ## Model Building

# %% [markdown]
# ## Prepare Dataset for Modelling

# %%
churn_data.shape
# Out:
# (7043, 21)

# %% [markdown]
# drop group columns

# %%
churn_data = churn_data.drop('tenure_group', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 churn_data = churn_data.drop('tenure_group', axis=1)
#
# File ~/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['tenure_group'] not found in axis"

# %%
churn_data.head()

# %% [markdown]
# ## Train_Test_Split

# %%
# 0.3, 0.7

# %%
from sklearn.model_selection import train_test_split

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
# y = mX + c

# %%
X = churn_data[["customerid","gender","seniorcitizen",
                "partner","dependents","tenure",
                "phoneservice","multiplelines","internetservice",
                "onlinesecurity","deviceprotection","techsupport",
                "streamingtv","streamingmovies","contract",
                "paperlessbilling","paymentmethod",
                "monthlycharges","totalcharges"]]

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity deviceprotection  \
# 0  No phone service             DSL             No               No
# 1                No             DSL            Yes              Yes
# 2                No             DSL            Yes               No
# 3  No phone service             DSL            Yes              Yes
# 4                No     Fiber optic             No               No
#
#   techsupport streamingtv streamingmovies        contract paperlessbilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                paymentmethod  monthlycharges  totalcharges
# 0           Electronic check           29.85         29.85
# 1               Mailed check           56.95       1889.50
# 2               Mailed check           53.85        108.15
# 3  Bank transfer (automatic)           42.30       1840.75
# 4           Electronic check           70.70        151.65

# %%
y = churn_data["churn"]

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: churn, dtype: object

# %%
y[0:5]
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: churn, dtype: object

# %%
train_data, test_data = train_test_split(churn_data,test_size = 0.30, random_state =42)

# %%
train_data.shape, test_data.shape
# Out:
# ((4930, 21), (2113, 21))

# %%
train_data.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 1695  4906-ZHGPK    Male              0     Yes        Yes      54
# 1095  7439-DKZTW    Male              0      No         No       1
# 3889  2592-HODOV    Male              0      No         No      13
# 3667  7826-VVKWT  Female              1     Yes        Yes      24
# 2902  1658-TJVOA  Female              1      No         No       6
#
#      phoneservice multiplelines internetservice       onlinesecurity  ...  \
# 1695          Yes           Yes             DSL                   No  ...
# 1095          Yes            No     Fiber optic                   No  ...
# 3889          Yes            No              No  No internet service  ...
# 3667          Yes            No     Fiber optic                   No  ...
# 2902          Yes            No     Fiber optic                  Yes  ...
#
#          deviceprotection          techsupport          streamingtv  \
# 1695                   No                  Yes                  Yes
# 1095                   No                   No                  Yes
# 3889  No internet service  No internet service  No internet service
# 3667                  Yes                   No                  Yes
# 2902                   No                   No                   No
#
#           streamingmovies        contract paperlessbilling  \
# 1695                   No        One year              Yes
# 1095                   No  Month-to-month              Yes
# 3889  No internet service        One year               No
# 3667                  Yes        Two year              Yes
# 2902                   No  Month-to-month              Yes
#
#                 paymentmethod monthlycharges  totalcharges  churn
# 1695         Electronic check          70.70       3770.00     No
# 1095         Electronic check          80.55         80.55     No
# 3889  Credit card (automatic)          19.30        259.65     No
# 3667         Electronic check          96.55       2263.45     No
# 2902         Electronic check          74.10        450.90     No
#
# [5 rows x 21 columns]

# %%
test_data.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# 2715          Yes               Yes              No  No internet service  ...
# 3825          Yes                No              No  No internet service  ...
# 1807          Yes                No     Fiber optic                   No  ...
# 132           Yes                No             DSL                   No  ...
#
#          deviceprotection          techsupport          streamingtv  \
# 185                    No                   No                   No
# 2715  No internet service  No internet service  No internet service
# 3825  No internet service  No internet service  No internet service
# 1807                  Yes                   No                   No
# 132                    No                  Yes                   No
#
#           streamingmovies        contract paperlessbilling  \
# 185                    No  Month-to-month              Yes
# 2715  No internet service  Month-to-month              Yes
# 3825  No internet service        Two year               No
# 1807                   No  Month-to-month               No
# 132                    No        Two year               No
#
#                   paymentmethod monthlycharges  totalcharges  churn
# 185            Electronic check          24.80         24.80    Yes
# 2715  Bank transfer (automatic)          25.25        996.45     No
# 3825               Mailed check          19.35       1031.70     No
# 1807           Electronic check          76.35         76.35    Yes
# 132   Bank transfer (automatic)          50.55       3260.10     No
#
# [5 rows x 21 columns]

# %%
label = 'churn'

# %%
print("Summary of churn variable:\n", train_data[label].describe())
# Out:
# Summary of churn variable:
#  count     4930
# unique       2
# top         No
# freq      3635
# Name: churn, dtype: object

# %% [markdown]
# ## basic model build

# %%
# %%time

save_path = 'models'
predictor = TabularPredictor(label=label, path=save_path).fit(train_data)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="models"
# Beginning AutoGluon training ...
# AutoGluon will save models to "models/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.16
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 20.6.0: Fri Dec 16 00:35:00 PST 2022; root:xnu-7195.141.49~1/RELEASE_X86_64
# Train Data Rows:    4930
# Train Data Columns: 20
# Label Column: churn
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['No', 'Yes']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = Yes, class 0 = No
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Yes) vs negative (No) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    9721.73 MB
# 	Train Data (Original)  Memory Usage: 5.15 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 6 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Unused Original Features (Count: 1): ['customerid']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['customerid']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  :  2 | ['monthlycharges', 'totalcharges']
# 		('int', [])    :  2 | ['seniorcitizen', 'tenure']
# 		('object', []) : 15 | ['gender', 'partner', 'dependents', 'phoneservice', 'multiplelines', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 10 | ['multiplelines', 'internetservice', 'onlinesecurity', 'onlinebackup', 'deviceprotection', ...]
# 		('float', [])     :  2 | ['monthlycharges', 'totalcharges']
# 		('int', [])       :  1 | ['tenure']
# 		('int', ['bool']) :  6 | ['gender', 'seniorcitizen', 'partner', 'dependents', 'phoneservice', ...]
# 	0.4s = Fit runtime
# 	19 features in original data used to generate 19 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.2 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.59s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.10141987829614604, Train Rows: 4430, Val Rows: 500
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.758	 = Validation score   (accuracy)
# 	6.78s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.732	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	Warning: Exception caused LightGBMXT to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: image not found
# Fitting model: LightGBM ...
# 	Warning: Exception caused LightGBM to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: image not found
# Fitting model: RandomForestGini ...
# 	0.774	 = Validation score   (accuracy)
# 	1.62s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.784	 = Validation score   (accuracy)
# 	1.11s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.81	 = Validation score   (accuracy)
# 	6.22s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.774	 = Validation score   (accuracy)
# 	1.14s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.768	 = Validation score   (accuracy)
# 	1.33s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.794	 = Validation score   (accuracy)
# 	7.23s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.782	 = Validation score   (accuracy)
# 	0.6s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.8	 = Validation score   (accuracy)
# 	10.1s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	Warning: Exception caused LightGBMLarge to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: image not found
# Fitting model: WeightedEnsemble_L2 ...
# 	0.81	 = Validation score   (accuracy)
# 	0.79s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 39.36s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("models/")
# CPU times: user 50.9 s, sys: 2.65 s, total: 53.6 s
# Wall time: 39.4 s

# %%
predictor.leaderboard(silent=True)
# Out:
#                   model  score_val  pred_time_val   fit_time  \
# 0              CatBoost      0.810       0.009264   6.221009
# 1   WeightedEnsemble_L2      0.810       0.011014   7.015123
# 2        NeuralNetTorch      0.800       0.018174  10.097422
# 3       NeuralNetFastAI      0.794       0.021280   7.227841
# 4      RandomForestEntr      0.784       0.081267   1.107146
# 5               XGBoost      0.782       0.011912   0.604633
# 6      RandomForestGini      0.774       0.072086   1.617554
# 7        ExtraTreesGini      0.774       0.149704   1.139024
# 8        ExtraTreesEntr      0.768       0.077858   1.331524
# 9        KNeighborsUnif      0.758       0.039726   6.779783
# 10       KNeighborsDist      0.732       0.026608   0.033781
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.009264           6.221009            1       True
# 1                 0.001750           0.794114            2       True
# 2                 0.018174          10.097422            1       True
# 3                 0.021280           7.227841            1       True
# 4                 0.081267           1.107146            1       True
# 5                 0.011912           0.604633            1       True
# 6                 0.072086           1.617554            1       True
# 7                 0.149704           1.139024            1       True
# 8                 0.077858           1.331524            1       True
# 9                 0.039726           6.779783            1       True
# 10                0.026608           0.033781            1       True
#
#     fit_order
# 0           5
# 1          11
# 2          10
# 3           8
# 4           4
# 5           9
# 6           3
# 7           6
# 8           7
# 9           1
# 10          2

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# load test data to make predictions

# %%
y_test = test_data[label]

# %%
y_test.head()
# Out:
# 185     Yes
# 2715     No
# 3825     No
# 1807    Yes
# 132      No
# Name: churn, dtype: object

# %%
y_test = test_data[label]  # values to predict

# %%
y_test [0:5]
# Out:
# 185     Yes
# 2715     No
# 3825     No
# 1807    Yes
# 132      No
# Name: churn, dtype: object

# %%
test_data_nolab = test_data.drop(columns=[label])  # delete label column to avoid cheating

# %%
test_data_nolab.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      phoneservice     multiplelines internetservice       onlinesecurity  \
# 185            No  No phone service             DSL                   No
# 2715          Yes               Yes              No  No internet service
# 3825          Yes                No              No  No internet service
# 1807          Yes                No     Fiber optic                   No
# 132           Yes                No             DSL                   No
#
#              onlinebackup     deviceprotection          techsupport  \
# 185                    No                   No                   No
# 2715  No internet service  No internet service  No internet service
# 3825  No internet service  No internet service  No internet service
# 1807                   No                  Yes                   No
# 132                    No                   No                  Yes
#
#               streamingtv      streamingmovies        contract  \
# 185                    No                   No  Month-to-month
# 2715  No internet service  No internet service  Month-to-month
# 3825  No internet service  No internet service        Two year
# 1807                   No                   No  Month-to-month
# 132                    No                   No        Two year
#
#      paperlessbilling              paymentmethod  monthlycharges  totalcharges
# 185               Yes           Electronic check           24.80         24.80
# 2715              Yes  Bank transfer (automatic)           25.25        996.45
# 3825               No               Mailed check           19.35       1031.70
# 1807               No           Electronic check           76.35         76.35
# 132                No  Bank transfer (automatic)           50.55       3260.10

# %%
save_path
# Out:
# 'models'

# %%
predictor

# %%
save_model_predictor = TabularPredictor.load(save_path)

# %%
save_model_predictor

# %%
y_pred = save_model_predictor.predict(test_data_nolab)

# %%
y_pred[0:5]
# Out:
# 185     Yes
# 2715     No
# 3825     No
# 1807    Yes
# 132      No
# Name: churn, dtype: object

# %%
print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: accuracy on test data: 0.8035967818267865
# Evaluations on test data:
# {
#     "accuracy": 0.8035967818267865,
#     "balanced_accuracy": 0.706229779507486,
#     "mcc": 0.4652323557407966,
#     "f1": 0.5769622833843018,
#     "precision": 0.6953316953316954,
#     "recall": 0.4930313588850174
# }
# Predictions:
#  185     Yes
# 2715     No
# 3825     No
# 1807    Yes
# 132      No
#        ...
# 5522    Yes
# 6377     No
# 5500     No
# 2392     No
# 6705     No
# Name: churn, Length: 2113, dtype: object

# %%
save_model_predictor.leaderboard(test_data, silent=True)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0              CatBoost    0.803597      0.810        0.017086       0.009264
# 1   WeightedEnsemble_L2    0.803597      0.810        0.021041       0.011014
# 2               XGBoost    0.803124      0.782        0.042561       0.011912
# 3        NeuralNetTorch    0.802177      0.800        0.046515       0.018174
# 4       NeuralNetFastAI    0.800284      0.794        0.683100       0.021280
# 5      RandomForestGini    0.798391      0.774        0.198247       0.072086
# 6      RandomForestEntr    0.793658      0.784        0.190450       0.081267
# 7        ExtraTreesGini    0.781827      0.774        0.279848       0.149704
# 8        ExtraTreesEntr    0.781354      0.768        0.297273       0.077858
# 9        KNeighborsUnif    0.773308      0.758        0.047625       0.039726
# 10       KNeighborsDist    0.766209      0.732        0.030749       0.026608
#
#      fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0    6.221009                 0.017086                0.009264
# 1    7.015123                 0.003955                0.001750
# 2    0.604633                 0.042561                0.011912
# 3   10.097422                 0.046515                0.018174
# 4    7.227841                 0.683100                0.021280
# 5    1.617554                 0.198247                0.072086
# 6    1.107146                 0.190450                0.081267
# 7    1.139024                 0.279848                0.149704
# 8    1.331524                 0.297273                0.077858
# 9    6.779783                 0.047625                0.039726
# 10   0.033781                 0.030749                0.026608
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            6.221009            1       True          5
# 1            0.794114            2       True         11
# 2            0.604633            1       True          9
# 3           10.097422            1       True         10
# 4            7.227841            1       True          8
# 5            1.617554            1       True          3
# 6            1.107146            1       True          4
# 7            1.139024            1       True          6
# 8            1.331524            1       True          7
# 9            6.779783            1       True          1
# 10           0.033781            1       True          2

# %%
save_model_predictor.feature_importance(test_data, silent=True)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['customerid']
#                   importance    stddev   p_value  n  p99_high   p99_low
# tenure              0.040322  0.004726  0.000022  5  0.050052  0.030592
# contract            0.031803  0.003093  0.000011  5  0.038171  0.025436
# internetservice     0.013914  0.007048  0.005781  5  0.028426 -0.000599
# monthlycharges      0.011169  0.004435  0.002445  5  0.020300  0.002038
# techsupport         0.007761  0.002380  0.000941  5  0.012663  0.002860
# onlinesecurity      0.007383  0.001968  0.000553  5  0.011436  0.003330
# paymentmethod       0.004733  0.003413  0.018095  5  0.011759 -0.002294
# paperlessbilling    0.002934  0.001584  0.007173  5  0.006195 -0.000327
# multiplelines       0.002840  0.003049  0.052854  5  0.009117 -0.003438
# streamingmovies    -0.000095  0.002047  0.538695  5  0.004119 -0.004309
# phoneservice       -0.000189  0.000423  0.813050  5  0.000682 -0.001061
# onlinebackup       -0.000852  0.001619  0.847721  5  0.002481 -0.004185
# partner            -0.000947  0.001739  0.854780  5  0.002634 -0.004527
# seniorcitizen      -0.001041  0.001225  0.934919  5  0.001481 -0.003563
# gender             -0.001325  0.000617  0.995682  5 -0.000055 -0.002596
# dependents         -0.001514  0.001130  0.979971  5  0.000812 -0.003841
# deviceprotection   -0.001609  0.001660  0.951975  5  0.001808 -0.005027
# streamingtv        -0.002366  0.002220  0.962156  5  0.002204 -0.006937
# totalcharges       -0.002934  0.003702  0.924470  5  0.004689 -0.010557

# %%
save_model_predictor.feature_importance(train_data, silent=True)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['customerid']
#                   importance    stddev       p_value  n  p99_high   p99_low
# tenure              0.045923  0.004119  7.681724e-06  5  0.054403  0.037442
# contract            0.036187  0.002682  3.593445e-06  5  0.041708  0.030665
# monthlycharges      0.017079  0.001833  1.569399e-05  5  0.020854  0.013304
# internetservice     0.016957  0.000819  6.507018e-07  5  0.018644  0.015271
# techsupport         0.010426  0.001446  4.325170e-05  5  0.013403  0.007449
# totalcharges        0.009574  0.001822  1.501311e-04  5  0.013326  0.005822
# paymentmethod       0.009047  0.001549  9.917339e-05  5  0.012236  0.005858
# onlinesecurity      0.008519  0.000951  1.835870e-05  5  0.010478  0.006560
# paperlessbilling    0.006815  0.001288  1.458954e-04  5  0.009467  0.004164
# onlinebackup        0.006450  0.002372  1.847238e-03  5  0.011333  0.001567
# multiplelines       0.005963  0.001938  1.169275e-03  5  0.009954  0.001973
# streamingtv         0.003408  0.001371  2.566761e-03  5  0.006231  0.000584
# seniorcitizen       0.002434  0.001004  2.806555e-03  5  0.004501  0.000367
# streamingmovies     0.002394  0.001087  3.949893e-03  5  0.004631  0.000156
# deviceprotection    0.001907  0.001481  2.252807e-02  5  0.004956 -0.001142
# dependents          0.001420  0.000688  4.956673e-03  5  0.002836  0.000004
# gender              0.000730  0.000844  6.252033e-02  5  0.002467 -0.001007
# partner             0.000609  0.000517  2.905735e-02  5  0.001673 -0.000456
# phoneservice        0.000041  0.000264  3.744342e-01  5  0.000585 -0.000504

# %%
test_data.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# 2715          Yes               Yes              No  No internet service  ...
# 3825          Yes                No              No  No internet service  ...
# 1807          Yes                No     Fiber optic                   No  ...
# 132           Yes                No             DSL                   No  ...
#
#          deviceprotection          techsupport          streamingtv  \
# 185                    No                   No                   No
# 2715  No internet service  No internet service  No internet service
# 3825  No internet service  No internet service  No internet service
# 1807                  Yes                   No                   No
# 132                    No                  Yes                   No
#
#           streamingmovies        contract paperlessbilling  \
# 185                    No  Month-to-month              Yes
# 2715  No internet service  Month-to-month              Yes
# 3825  No internet service        Two year               No
# 1807                   No  Month-to-month               No
# 132                    No        Two year               No
#
#                   paymentmethod monthlycharges  totalcharges  churn
# 185            Electronic check          24.80         24.80    Yes
# 2715  Bank transfer (automatic)          25.25        996.45     No
# 3825               Mailed check          19.35       1031.70     No
# 1807           Electronic check          76.35         76.35    Yes
# 132   Bank transfer (automatic)          50.55       3260.10     No
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Improving Predictive Performance

# %% [markdown]
# Our basic model build took 31.9 seconds, we can improve our model by setting a shorter time limit of 25 seconds

# %%
#time_limit = 25

# %% [markdown]
# We can also set an evaluation metric

# %%
#metric = 'roc_auc'

# %%
#save_path = 'agModels-predictchurnimproved'

# %% [markdown]
# .. and also preset our models for best quality fit

# %%
# %%time

time_limit = 20
save_path = 'AutogluonModels'
metric = 'roc_auc'
predictor = TabularPredictor(label, eval_metric=metric).fit(train_data, time_limit=time_limit, presets='best_quality')
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230219_203642/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 20s
# AutoGluon will save models to "AutogluonModels/ag-20230219_203642/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.16
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 20.6.0: Fri Dec 16 00:35:00 PST 2022; root:xnu-7195.141.49~1/RELEASE_X86_64
# Train Data Rows:    4930
# Train Data Columns: 20
# Label Column: churn
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['No', 'Yes']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = Yes, class 0 = No
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Yes) vs negative (No) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5266.57 MB
# 	Train Data (Original)  Memory Usage: 5.15 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 6 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Unused Original Features (Count: 1): ['customerid']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['customerid']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  :  2 | ['monthlycharges', 'totalcharges']
# 		('int', [])    :  2 | ['seniorcitizen', 'tenure']
# 		('object', []) : 15 | ['gender', 'partner', 'dependents', 'phoneservice', 'multiplelines', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 10 | ['multiplelines', 'internetservice', 'onlinesecurity', 'onlinebackup', 'deviceprotection', ...]
# 		('float', [])     :  2 | ['monthlycharges', 'totalcharges']
# 		('int', [])       :  1 | ['tenure']
# 		('int', ['bool']) :  6 | ['gender', 'seniorcitizen', 'partner', 'dependents', 'phoneservice', ...]
# 	0.5s = Fit runtime
# 	19 features in original data used to generate 19 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.2 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.68s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 19.32s of the 19.31s of remaining time.
# 	0.731	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 19.24s of the 19.23s of remaining time.
# 	0.72	 = Validation score   (roc_auc)
# 	0.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 19.16s of the 19.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: image not found
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 19.05s of the 19.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/macbook/opt/anaconda3/envs/tescochurn/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: image not found
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 18.95s of the 18.95s of remaining time.
# 	0.8207	 = Validation score   (roc_auc)
# 	1.31s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 17.1s of the 17.1s of remaining time.
# 	0.8202	 = Validation score   (roc_auc)
# 	1.61s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 14.6s of the 14.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Ran out of time, early stopping on iteration 93.
# 	Ran out of time, early stopping on iteration 99.
# 	Ran out of time, early stopping on iteration 143.
# 	Ran out of time, early stopping on iteration 141.
# 	Ran out of time, early stopping on iteration 113.
# 	Ran out of time, early stopping on iteration 131.
# 	Ran out of time, early stopping on iteration 178.
# 	Ran out of time, early stopping on iteration 209.
# 	0.8428	 = Validation score   (roc_auc)
# 	13.89s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 0.39s of the 0.39s of remaining time.
# 	0.8083	 = Validation score   (roc_auc)
# 	2.32s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 19.32s of the -2.7s of remaining time.
# 	0.843	 = Validation score   (roc_auc)
# 	1.27s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 24.03s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230219_203642/")
# CPU times: user 31.8 s, sys: 1.93 s, total: 33.7 s
# Wall time: 24.2 s

# %%
predictor.leaderboard(test_data, silent=True)
# Out:
#                      model  score_test  score_val  pred_time_test  \
# 0      WeightedEnsemble_L2    0.860705   0.842965        1.153371
# 1          CatBoost_BAG_L1    0.860653   0.842803        0.062715
# 2  RandomForestGini_BAG_L1    0.837488   0.820652        0.548476
# 3  RandomForestEntr_BAG_L1    0.837081   0.820211        0.522152
# 4    ExtraTreesGini_BAG_L1    0.831588   0.808307        0.961456
# 5    KNeighborsUnif_BAG_L1    0.751180   0.730969        0.008581
# 6    KNeighborsDist_BAG_L1    0.742869   0.720020        0.008434
#
#    pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       1.004899  18.090163                 0.011594                0.001209
# 1       0.119853  13.890118                 0.062715                0.119853
# 2       0.400431   1.309332                 0.548476                0.400431
# 3       0.462974   1.607918                 0.522152                0.462974
# 4       0.485309   2.320530                 0.961456                0.485309
# 5       0.013133   0.013325                 0.008581                0.013133
# 6       0.020432   0.014443                 0.008434                0.020432
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           1.268352            2       True          7
# 1          13.890118            1       True          5
# 2           1.309332            1       True          3
# 3           1.607918            1       True          4
# 4           2.320530            1       True          6
# 5           0.013325            1       True          1
# 6           0.014443            1       True          2

# %%
predictor.feature_importance(test_data, silent=True)

# %% [markdown]
# Model building results show only 7 models can complete iteration within time limit set

# %%
#Bringing it all together

# %%
test_data["predicted_churn"] = y_pred

# %%
test_data.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# 2715          Yes               Yes              No  No internet service  ...
# 3825          Yes                No              No  No internet service  ...
# 1807          Yes                No     Fiber optic                   No  ...
# 132           Yes                No             DSL                   No  ...
#
#               techsupport          streamingtv      streamingmovies  \
# 185                    No                   No                   No
# 2715  No internet service  No internet service  No internet service
# 3825  No internet service  No internet service  No internet service
# 1807                   No                   No                   No
# 132                   Yes                   No                   No
#
#             contract paperlessbilling              paymentmethod  \
# 185   Month-to-month              Yes           Electronic check
# 2715  Month-to-month              Yes  Bank transfer (automatic)
# 3825        Two year               No               Mailed check
# 1807  Month-to-month               No           Electronic check
# 132         Two year               No  Bank transfer (automatic)
#
#      monthlycharges totalcharges  churn  predicted_churn
# 185           24.80        24.80    Yes              Yes
# 2715          25.25       996.45     No               No
# 3825          19.35      1031.70     No               No
# 1807          76.35        76.35    Yes              Yes
# 132           50.55      3260.10     No               No
#
# [5 rows x 22 columns]

# %%
test_data.sample(10)
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 471   3583-EKAPL    Male              0      No         No       1
# 1018  3748-FVMZZ    Male              0      No         No       4
# 1578  1205-WNWPJ  Female              0      No         No       7
# 1886  6695-FRVEC    Male              0     Yes        Yes      67
# 2499  6061-GWWAV    Male              0      No        Yes      41
# 5597  6284-AHOOQ    Male              1      No         No      22
# 2517  5186-SAMNZ    Male              1      No         No       1
# 712   9661-JALZV  Female              0      No         No      58
# 465   2996-XAUVF    Male              0      No         No      70
# 6451  4868-AADLV    Male              1     Yes        Yes      66
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 471           Yes                No             DSL                   No  ...
# 1018           No  No phone service             DSL                   No  ...
# 1578          Yes                No             DSL                   No  ...
# 1886          Yes                No             DSL                  Yes  ...
# 2499          Yes                No             DSL                  Yes  ...
# 5597          Yes               Yes     Fiber optic                   No  ...
# 2517          Yes                No     Fiber optic                   No  ...
# 712           Yes               Yes              No  No internet service  ...
# 465            No  No phone service             DSL                   No  ...
# 6451          Yes               Yes     Fiber optic                  Yes  ...
#
#               techsupport          streamingtv      streamingmovies  \
# 471                    No                   No                  Yes
# 1018                  Yes                   No                  Yes
# 1578                  Yes                  Yes                   No
# 1886                  Yes                   No                   No
# 2499                   No                  Yes                   No
# 5597                  Yes                  Yes                   No
# 2517                   No                   No                   No
# 712   No internet service  No internet service  No internet service
# 465                   Yes                   No                  Yes
# 6451                  Yes                  Yes                  Yes
#
#             contract paperlessbilling              paymentmethod  \
# 471   Month-to-month              Yes           Electronic check
# 1018  Month-to-month              Yes           Electronic check
# 1578  Month-to-month              Yes               Mailed check
# 1886        Two year              Yes  Bank transfer (automatic)
# 2499        One year               No               Mailed check
# 5597  Month-to-month              Yes  Bank transfer (automatic)
# 2517  Month-to-month              Yes  Bank transfer (automatic)
# 712         Two year              Yes    Credit card (automatic)
# 465         Two year              Yes               Mailed check
# 6451        One year              Yes           Electronic check
#
#      monthlycharges totalcharges  churn  predicted_churn
# 471           55.00        55.00    Yes              Yes
# 1018          40.05       162.45     No               No
# 1578          59.50       415.95    Yes               No
# 1886          60.40      3953.70     No               No
# 2499          70.20      2894.55     No               No
# 5597          90.50      1910.60    Yes               No
# 2517          69.50        69.50    Yes              Yes
# 712           24.70      1519.00     No               No
# 465           40.05      2799.75     No               No
# 6451         116.25      7862.25     No               No
#
# [10 rows x 22 columns]
